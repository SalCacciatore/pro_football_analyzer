# %%
# %%
import pandas as pd
import xgboost as xgb
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split, GridSearchCV

import matplotlib.pyplot as plt
import seaborn as sns
import pickle



# %%
YEARS = [2018, 2019, 2020, 2021, 2022, 2023,2024]

# %%
data_all = pd.DataFrame()

def calculate_seconds(row):
    if row['qtr'] != 5:
        return 3600 - row['game_seconds_remaining']
    else:
        return 600 - row['game_seconds_remaining'] + 3600


def get_quarter_value(dataf):
    if 'END QUARTER' in dataf['desc']:
        return dataf['level_0']
    else:
        return None

for i in YEARS:  
    i_data = pd.read_csv('https://github.com/nflverse/nflverse-data/releases/download/pbp/' \
                   'play_by_play_' + str(i) + '.csv.gz',
                   compression= 'gzip', low_memory= False)

    data_all = pd.concat([data_all,i_data])

ppr = 1

data = data_all.loc[data_all.season_type=='REG']
#data = data_all.loc[(data_all.play_type.isin(['no_play','pass','run'])) & (data_all.epa.isna()==False)]
#data.loc[data['pass']==1, 'play_type'] = 'pass'
#data.loc[data.rush==1, 'play_type'] = 'run'
data.reset_index(drop=True, inplace=True)
data['turnover'] = data['interception'] + data['fumble_lost']
data = data.dropna(subset=['posteam'])
data['inside_10'] = (data['yardline_100'] < 10).astype(int)
data['20+_play'] = (data['yards_gained'] > 19).astype(int)
data['short_pass'] = (data['air_yards'] < 10).astype(int)
data['medium_pass'] = ((data['air_yards'] > 9)&(data['air_yards']<20)).astype(int)
data['deep_pass'] = (data['air_yards'] > 19).astype(int)
data['end_zone_target'] = (data['yardline_100'] - data['air_yards']) <= 0
data['fantasy_points'] = (
    data['complete_pass'] * ppr +          # 1 point per completion
    data['touchdown'] * 6 +           # 6 points per touchdown
    data['yards_gained'] * 0.1        # 0.1 points per yard gained
)
data['distance_to_EZ_after_target'] = data['yardline_100'] - data['air_yards']
# Out:
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\851295465.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['turnover'] = data['interception'] + data['fumble_lost']
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\851295465.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['turnover'] = data['interception'] + data['fumble_lost']
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\851295465.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['inside_10'] = (data['yardline_100'] < 10).astype(int)
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\851295465.py:51: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['20+_play'] = (data['yards_gained'] > 19).astype(int)
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\851295465.py:52: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['short_pass'] = (data['air_yards'] < 10).astype(int)
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\851295465.py:53: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['medium_pass'] = ((data['air_yards'] > 9)&(data['air_yards']<20)).astype(int)
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\851295465.py:54: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['deep_pass'] = (data['air_yards'] > 19).astype(int)
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\851295465.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['end_zone_target'] = (data['yardline_100'] - data['air_yards']) <= 0
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\851295465.py:56: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['fantasy_points'] = (
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\851295465.py:61: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['distance_to_EZ_after_target'] = data['yardline_100'] - data['air_yards']

# %%
def total_finder(home_or_away,home_total,away_total):
    if home_or_away == 'home':
        total = home_total
    else:
        total = away_total 
    return total

# %%
    data.reset_index(drop=True, inplace=True)

    data = data[data['two_point_attempt']==0]


    # derive implied team total from betting market data
    data['home_implied_total'] = abs(data['total_line'] / 2 + data['spread_line'] / 2)
    data['away_implied_total'] = abs(data['total_line'] / 2 - data['spread_line'] / 2)

    # Use list comprehension with zip for more efficient row-wise operations
    data['implied_posteam_total'] = [
    total_finder(has_ball, home_number, away_number)
        for has_ball, home_number, away_number in zip(data['posteam_type'], data['home_implied_total'], data['away_implied_total'])
]
# Out:
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\1090877097.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['home_implied_total'] = abs(data['total_line'] / 2 + data['spread_line'] / 2)
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\1090877097.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['away_implied_total'] = abs(data['total_line'] / 2 - data['spread_line'] / 2)
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\1090877097.py:11: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['implied_posteam_total'] = [

# %%
    
    # we only want throws to a receiver, aka plays with air yardage (no running plays, sacks, throwaways etc.)
    throws = data[data['air_yards'].notna()]
    # only data before the current szn
    throws = throws[throws['season']!=2024]
    throws = throws[throws['receiver_player_name'].notna()]
    throws = throws[throws['pass_location'].notna()]

    
    df = throws[['receiver_player_name','receiver_player_id','posteam','pass','cp','game_id','complete_pass','inside_10','air_yards','yardline_100','ydstogo','implied_posteam_total','yards_gained','fantasy_points','pass_touchdown','down','pass_location','week','season','home_implied_total','away_implied_total','posteam_type','qb_hit','end_zone_target', 'distance_to_EZ_after_target']]

# %% [markdown]
# # Season-over-season Comparison

# %%
def load_models():
    with open('yardage_model.pkl', 'rb') as file:
        yardage_model = pickle.load(file)
    
    with open('touchdown_model.pkl', 'rb') as file:
        touchdown_model = pickle.load(file)

    return yardage_model, touchdown_model

# %%
yardage_model, touchdown_model = load_models()

# %%
df['season'].value_counts()
# Out:
# season
# 2021    18055
# 2023    17483
# 2020    17307
# 2022    17305
# 2018    17172
# 2019    17140
# Name: count, dtype: int64

# %%
new_predictors = [
    'air_yards', 'yardline_100', 'ydstogo',
    'down', 'pass_location', 'season', 'qb_hit', 'end_zone_target', 'distance_to_EZ_after_target'
]

test_df = df[new_predictors]

test_df.head()
# Out:
#     air_yards  yardline_100  ydstogo  down pass_location  season  qb_hit  \
# 2         8.0          80.0       15   1.0         right    2018     0.0
# 5         4.0          39.0       10   1.0         right    2018     0.0
# 6        -3.0          39.0       10   2.0          left    2018     0.0
# 7        24.0          39.0       10   3.0          left    2018     0.0
# 10        1.0           1.0        1   3.0         right    2018     0.0
#
#     end_zone_target  distance_to_EZ_after_target
# 2             False                         72.0
# 5             False                         35.0
# 6             False                         42.0
# 7             False                         15.0
# 10             True                          0.0

# %%
test_df = pd.get_dummies(test_df, columns=['pass_location'], drop_first=True)


# Add predictions to the new dataset (optional)
df['xYards'] = yardage_model.predict(test_df)
df['xTDs'] = touchdown_model.predict(test_df)
#df['xFPs'] = best_model.predict(test_df)
df['compositeXFP'] = df['cp'] * ppr + df['xTDs'] * 6 + df['xYards'] * 0.1
# Out:
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\1150515730.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xYards'] = yardage_model.predict(test_df)
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\1150515730.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xTDs'] = touchdown_model.predict(test_df)
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\1150515730.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['compositeXFP'] = df['cp'] * ppr + df['xTDs'] * 6 + df['xYards'] * 0.1

# %%
df[['compositeXFP','fantasy_points']].corr()
# Out:
#                 compositeXFP  fantasy_points
# compositeXFP        1.000000        0.278306
# fantasy_points      0.278306        1.000000

# %%
receivers = df.groupby(['receiver_player_id','posteam','season']).agg({'receiver_player_name':'max','pass':'sum','xTDs':'sum','pass_touchdown':'sum','xYards':'sum','yards_gained':'sum','cp':'sum','complete_pass':'sum','fantasy_points':'sum','compositeXFP':'sum'}).sort_values('compositeXFP',ascending=False)

# %%
receivers
# Out:
#                                   receiver_player_name  pass       xTDs  \
# receiver_player_id posteam season
# 00-0033908         LA      2021                 C.Kupp   191  11.309783
# 00-0036358         DAL     2023                 C.Lamb   181  12.028312
# 00-0031381         LV      2022                D.Adams   180  10.228611
# 00-0036322         MIN     2022            J.Jefferson   184  10.681751
# 00-0032765         NO      2019               M.Thomas   185   7.270545
# ...                                                ...   ...        ...
# 00-0035289         JAX     2020           G.Minshew II     1   0.000698
# 00-0019596         NE      2018                T.Brady     1   0.002885
# 00-0029263         SEA     2018               R.Wilson     1   0.002186
# 00-0025944         BUF     2018             S.Hauschka     1   0.059686
# 00-0033057         CLE     2022              J.Conklin     1   0.002385
#
#                                    pass_touchdown       xYards  yards_gained  \
# receiver_player_id posteam season
# 00-0033908         LA      2021              16.0  1441.202759        1947.0
# 00-0036358         DAL     2023              12.0  1385.905273        1749.0
# 00-0031381         LV      2022              14.0  1525.546143        1516.0
# 00-0036322         MIN     2022               8.0  1452.039917        1819.0
# 00-0032765         NO      2019               9.0  1457.892822        1725.0
# ...                                           ...          ...           ...
# 00-0035289         JAX     2020               0.0     0.929980           0.0
# 00-0019596         NE      2018               0.0     3.413498           6.0
# 00-0029263         SEA     2018               0.0     0.510591         -11.0
# 00-0025944         BUF     2018               0.0    -0.477245           0.0
# 00-0033057         CLE     2022               0.0     0.462784           0.0
#
#                                            cp  complete_pass  fantasy_points  \
# receiver_player_id posteam season
# 00-0033908         LA      2021    129.081419          145.0           441.7
# 00-0036358         DAL     2023    117.402901          135.0           381.9
# 00-0031381         LV      2022    112.967685          100.0           341.6
# 00-0036322         MIN     2022    116.943704          128.0           357.9
# 00-0032765         NO      2019    128.447433          149.0           375.5
# ...                                       ...            ...             ...
# 00-0035289         JAX     2020      0.596584            1.0             1.0
# 00-0019596         NE      2018      0.329838            1.0             1.6
# 00-0029263         SEA     2018      0.570121            1.0            -0.1
# 00-0025944         BUF     2018      0.298615            0.0             0.0
# 00-0033057         CLE     2022      0.454621            0.0             0.0
#
#                                    compositeXFP
# receiver_player_id posteam season
# 00-0033908         LA      2021      341.060393
# 00-0036358         DAL     2023      328.163300
# 00-0031381         LV      2022      326.893961
# 00-0036322         MIN     2022      326.238200
# 00-0032765         NO      2019      317.859992
# ...                                         ...
# 00-0035289         JAX     2020        0.693767
# 00-0019596         NE      2018        0.688499
# 00-0029263         SEA     2018        0.634296
# 00-0025944         BUF     2018        0.609005
# 00-0033057         CLE     2022        0.515212
#
# [3159 rows x 10 columns]

# %%
receivers_qual = receivers[receivers['pass']>=20]

# %%
receivers
# Out:
#                                   receiver_player_name  pass       xTDs  \
# receiver_player_id posteam season
# 00-0033908         LA      2021                 C.Kupp   191  11.309783
# 00-0036358         DAL     2023                 C.Lamb   181  12.028312
# 00-0031381         LV      2022                D.Adams   180  10.228611
# 00-0036322         MIN     2022            J.Jefferson   184  10.681751
# 00-0032765         NO      2019               M.Thomas   185   7.270545
# ...                                                ...   ...        ...
# 00-0035289         JAX     2020           G.Minshew II     1   0.000698
# 00-0019596         NE      2018                T.Brady     1   0.002885
# 00-0029263         SEA     2018               R.Wilson     1   0.002186
# 00-0025944         BUF     2018             S.Hauschka     1   0.059686
# 00-0033057         CLE     2022              J.Conklin     1   0.002385
#
#                                    pass_touchdown       xYards  yards_gained  \
# receiver_player_id posteam season
# 00-0033908         LA      2021              16.0  1441.202759        1947.0
# 00-0036358         DAL     2023              12.0  1385.905273        1749.0
# 00-0031381         LV      2022              14.0  1525.546143        1516.0
# 00-0036322         MIN     2022               8.0  1452.039917        1819.0
# 00-0032765         NO      2019               9.0  1457.892822        1725.0
# ...                                           ...          ...           ...
# 00-0035289         JAX     2020               0.0     0.929980           0.0
# 00-0019596         NE      2018               0.0     3.413498           6.0
# 00-0029263         SEA     2018               0.0     0.510591         -11.0
# 00-0025944         BUF     2018               0.0    -0.477245           0.0
# 00-0033057         CLE     2022               0.0     0.462784           0.0
#
#                                            cp  complete_pass  fantasy_points  \
# receiver_player_id posteam season
# 00-0033908         LA      2021    129.081419          145.0           441.7
# 00-0036358         DAL     2023    117.402901          135.0           381.9
# 00-0031381         LV      2022    112.967685          100.0           341.6
# 00-0036322         MIN     2022    116.943704          128.0           357.9
# 00-0032765         NO      2019    128.447433          149.0           375.5
# ...                                       ...            ...             ...
# 00-0035289         JAX     2020      0.596584            1.0             1.0
# 00-0019596         NE      2018      0.329838            1.0             1.6
# 00-0029263         SEA     2018      0.570121            1.0            -0.1
# 00-0025944         BUF     2018      0.298615            0.0             0.0
# 00-0033057         CLE     2022      0.454621            0.0             0.0
#
#                                    compositeXFP
# receiver_player_id posteam season
# 00-0033908         LA      2021      341.060393
# 00-0036358         DAL     2023      328.163300
# 00-0031381         LV      2022      326.893961
# 00-0036322         MIN     2022      326.238200
# 00-0032765         NO      2019      317.859992
# ...                                         ...
# 00-0035289         JAX     2020        0.693767
# 00-0019596         NE      2018        0.688499
# 00-0029263         SEA     2018        0.634296
# 00-0025944         BUF     2018        0.609005
# 00-0033057         CLE     2022        0.515212
#
# [3159 rows x 10 columns]

# %%
receivers_qual.reset_index().sort_values(['receiver_player_id', 'season'])
# Out:
#      receiver_player_id posteam  season receiver_player_name  pass      xTDs  \
# 798          00-0021547     LAC    2018              A.Gates    45  3.793382
# 399          00-0022127     DAL    2019             J.Witten    83  3.410192
# 159          00-0022921     ARI    2018         L.Fitzgerald   112  6.013919
# 177          00-0022921     ARI    2019         L.Fitzgerald   107  6.194704
# 488          00-0022921     ARI    2020         L.Fitzgerald    72  2.071367
# ...                 ...     ...     ...                  ...   ...       ...
# 23           00-0039075      LA    2023              P.Nacua   160  6.575704
# 581          00-0039139     DET    2023              J.Gibbs    71  1.806288
# 867          00-0039144      GB    2023           L.Musgrave    46  1.417642
# 245          00-0039146      GB    2023               J.Reed    94  5.893373
# 1154         00-0039165     SEA    2023         Z.Charbonnet    40  0.209779
#
#       pass_touchdown       xYards  yards_gained          cp  complete_pass  \
# 798              2.0   310.046295         333.0   27.173962           28.0
# 399              4.0   570.964417         529.0   57.494382           63.0
# 159              6.0   880.963379         734.0   72.544649           69.0
# 177              4.0   798.765869         835.0   73.160045           73.0
# 488              1.0   524.440125         409.0   52.608162           54.0
# ...              ...          ...           ...         ...            ...
# 23               6.0  1289.263794        1486.0  108.953619          105.0
# 581              1.0   381.663513         316.0   56.332290           52.0
# 867              1.0   345.465942         352.0   31.674964           34.0
# 245              8.0   734.636780         793.0   59.541225           64.0
# 1154             0.0   204.455643         209.0   31.176665           33.0
#
#       fantasy_points  compositeXFP
# 798             79.3     80.938884
# 399            139.9    135.051976
# 159            178.4    196.724504
# 177            192.5    190.204855
# 488            100.9    117.480378
# ...              ...           ...
# 23             289.6    277.334217
# 581             95.6    105.336372
# 867             75.2     74.727413
# 245            191.3    168.365147
# 1154            53.9     52.880907
#
# [1557 rows x 13 columns]

# %%
df = receivers_qual.reset_index().sort_values(['receiver_player_id', 'season'])

# Create lagged columns for the next season's stats
for col in ['xTDs', 'pass_touchdown', 'xYards', 'yards_gained', 'cp', 'complete_pass','fantasy_points', 'compositeXFP']:
    df[f'{col}_next'] = df.groupby('receiver_player_id')[col].shift(-1)

# Drop rows where the next season's data is missing (last season for each player)
df_lagged = df.dropna(subset=[f'{col}_next' for col in ['xTDs', 'pass_touchdown', 'xYards', 'yards_gained', 'cp', 'complete_pass','fantasy_points', 'compositeXFP']])

# %%
df.head(20)
# Out:
#      receiver_player_id posteam  season receiver_player_name  pass      xTDs  \
# 798          00-0021547     LAC    2018              A.Gates    45  3.793382
# 399          00-0022127     DAL    2019             J.Witten    83  3.410192
# 159          00-0022921     ARI    2018         L.Fitzgerald   112  6.013919
# 177          00-0022921     ARI    2019         L.Fitzgerald   107  6.194704
# 488          00-0022921     ARI    2020         L.Fitzgerald    72  2.071367
# 693          00-0022943      NO    2018             B.Watson    46  4.364765
# 1335         00-0022943      NE    2019             B.Watson    24  1.378371
# 1400         00-0023564     PHI    2018            D.Sproles    23  1.376291
# 1061         00-0024221     WAS    2018              V.Davis    36  0.990651
# 1211         00-0024243      GB    2021              M.Lewis    28  2.130812
# 1396         00-0024334     SEA    2018           B.Marshall    23  0.903884
# 1163         00-0024389     TEN    2019            De.Walker    31  1.434003
# 1410         00-0025394     WAS    2018           A.Peterson    26  0.480599
# 1529         00-0025394     WAS    2019           A.Peterson    23  0.367350
# 1055         00-0025396      NO    2018               T.Ginn    30  2.373526
# 569          00-0025396      NO    2019               T.Ginn    56  4.056949
# 1518         00-0025399      LV    2018              M.Lynch    20  1.179965
# 883          00-0025418     CAR    2018              G.Olsen    38  2.753878
# 350          00-0025418     CAR    2019              G.Olsen    82  4.370691
# 948          00-0025418     SEA    2020              G.Olsen    37  3.134345
#
#       pass_touchdown      xYards  yards_gained         cp  ...  \
# 798              2.0  310.046295         333.0  27.173962  ...
# 399              4.0  570.964417         529.0  57.494382  ...
# 159              6.0  880.963379         734.0  72.544649  ...
# 177              4.0  798.765869         835.0  73.160045  ...
# 488              1.0  524.440125         409.0  52.608162  ...
# 693              2.0  365.639679         400.0  29.137302  ...
# 1335             0.0  176.140900         173.0  15.453680  ...
# 1400             2.0  124.240898         160.0  17.396862  ...
# 1061             2.0  312.337250         367.0  22.395950  ...
# 1211             0.0  160.565704         214.0  19.881775  ...
# 1396             1.0  194.008530         136.0  13.646339  ...
# 1163             2.0  228.315613         215.0  20.567200  ...
# 1410             1.0  143.061844         208.0  20.414077  ...
# 1529             0.0  109.799454         142.0  17.924322  ...
# 1055             2.0  283.107178         209.0  17.385297  ...
# 569              2.0  499.710510         421.0  32.226284  ...
# 1518             0.0   96.898903          84.0  15.113686  ...
# 883              4.0  310.213104         291.0  25.220772  ...
# 350              2.0  654.056458         597.0  53.428932  ...
# 948              1.0  255.346420         239.0  23.289061  ...
#
#       fantasy_points  compositeXFP  xTDs_next  pass_touchdown_next  \
# 798             79.3     80.938884        NaN                  NaN
# 399            139.9    135.051976        NaN                  NaN
# 159            178.4    196.724504   6.194704                  4.0
# 177            192.5    190.204855   2.071367                  1.0
# 488            100.9    117.480378        NaN                  NaN
# 693             87.0     91.889861   1.378371                  0.0
# 1335            34.3     41.337994        NaN                  NaN
# 1400            43.0     38.078697        NaN                  NaN
# 1061            73.7     59.573582        NaN                  NaN
# 1211            44.4     48.723220        NaN                  NaN
# 1396            30.6     38.470495        NaN                  NaN
# 1163            54.5     52.002782        NaN                  NaN
# 1410            46.8     37.603855   0.367350                  0.0
# 1529            31.2     31.108369        NaN                  NaN
# 1055            49.9     59.937171   4.056949                  2.0
# 569             84.1    106.539027        NaN                  NaN
# 1518            23.4     31.883370        NaN                  NaN
# 883             80.1     72.765352   4.370691                  2.0
# 350            129.7    145.058724   3.134345                  1.0
# 948             59.9     67.629773        NaN                  NaN
#
#       xYards_next  yards_gained_next    cp_next  complete_pass_next  \
# 798           NaN                NaN        NaN                 NaN
# 399           NaN                NaN        NaN                 NaN
# 159    798.765869              835.0  73.160045                73.0
# 177    524.440125              409.0  52.608162                54.0
# 488           NaN                NaN        NaN                 NaN
# 693    176.140900              173.0  15.453680                17.0
# 1335          NaN                NaN        NaN                 NaN
# 1400          NaN                NaN        NaN                 NaN
# 1061          NaN                NaN        NaN                 NaN
# 1211          NaN                NaN        NaN                 NaN
# 1396          NaN                NaN        NaN                 NaN
# 1163          NaN                NaN        NaN                 NaN
# 1410   109.799454              142.0  17.924322                17.0
# 1529          NaN                NaN        NaN                 NaN
# 1055   499.710510              421.0  32.226284                30.0
# 569           NaN                NaN        NaN                 NaN
# 1518          NaN                NaN        NaN                 NaN
# 883    654.056458              597.0  53.428932                52.0
# 350    255.346420              239.0  23.289061                24.0
# 948           NaN                NaN        NaN                 NaN
#
#       fantasy_points_next  compositeXFP_next
# 798                   NaN                NaN
# 399                   NaN                NaN
# 159                 192.5         190.204855
# 177                 100.9         117.480378
# 488                   NaN                NaN
# 693                  34.3          41.337994
# 1335                  NaN                NaN
# 1400                  NaN                NaN
# 1061                  NaN                NaN
# 1211                  NaN                NaN
# 1396                  NaN                NaN
# 1163                  NaN                NaN
# 1410                 31.2          31.108369
# 1529                  NaN                NaN
# 1055                 84.1         106.539027
# 569                   NaN                NaN
# 1518                  NaN                NaN
# 883                 129.7         145.058724
# 350                  59.9          67.629773
# 948                   NaN                NaN
#
# [20 rows x 21 columns]

# %%
df_lagged
# Out:
#      receiver_player_id posteam  season receiver_player_name  pass      xTDs  \
# 159          00-0022921     ARI    2018         L.Fitzgerald   112  6.013919
# 177          00-0022921     ARI    2019         L.Fitzgerald   107  6.194704
# 693          00-0022943      NO    2018             B.Watson    46  4.364765
# 1410         00-0025394     WAS    2018           A.Peterson    26  0.480599
# 1055         00-0025396      NO    2018               T.Ginn    30  2.373526
# ...                 ...     ...     ...                  ...   ...       ...
# 1215         00-0038117     NYG    2022           W.Robinson    31  0.639919
# 1227         00-0038120     NYJ    2022              Br.Hall    31  1.119950
# 438          00-0038124      GB    2022             C.Watson    66  5.519179
# 510          00-0038129      TB    2022              C.Otton    65  4.337548
# 1256         00-0038134     SEA    2022             K.Walker    35  0.138136
#
#       pass_touchdown      xYards  yards_gained         cp  ...  \
# 159              6.0  880.963379         734.0  72.544649  ...
# 177              4.0  798.765869         835.0  73.160045  ...
# 693              2.0  365.639679         400.0  29.137302  ...
# 1410             1.0  143.061844         208.0  20.414077  ...
# 1055             2.0  283.107178         209.0  17.385297  ...
# ...              ...         ...           ...        ...  ...
# 1215             1.0  224.932175         227.0  22.078208  ...
# 1227             1.0  192.434555         218.0  21.799425  ...
# 438              7.0  560.143677         611.0  38.034695  ...
# 510              2.0  437.800903         391.0  45.103641  ...
# 1256             0.0  174.778717         165.0  28.066606  ...
#
#       fantasy_points  compositeXFP  xTDs_next  pass_touchdown_next  \
# 159            178.4    196.724504   6.194704                  4.0
# 177            192.5    190.204855   2.071367                  1.0
# 693             87.0     91.889861   1.378371                  0.0
# 1410            46.8     37.603855   0.367350                  0.0
# 1055            49.9     59.937171   4.056949                  2.0
# ...              ...           ...        ...                  ...
# 1215            51.7     48.410937   1.013247                  1.0
# 1227            46.8     47.762584   1.113889                  4.0
# 438            144.1    127.164136   6.148241                  5.0
# 510             93.1    114.909020   3.377167                  4.0
# 1256            49.5     46.373292   0.277406                  1.0
#
#       xYards_next  yards_gained_next    cp_next  complete_pass_next  \
# 159    798.765869              835.0  73.160045                73.0
# 177    524.440125              409.0  52.608162                54.0
# 693    176.140900              173.0  15.453680                17.0
# 1410   109.799454              142.0  17.924322                17.0
# 1055   499.710510              421.0  32.226284                30.0
# ...           ...                ...        ...                 ...
# 1215   527.911743              525.0  56.055348                60.0
# 1227   498.789948              591.0  73.959531                76.0
# 438    439.387939              422.0  28.629502                28.0
# 510    453.356232              452.0  46.431071                47.0
# 1256   185.228836              259.0  28.642744                29.0
#
#       fantasy_points_next  compositeXFP_next
# 159                 192.5         190.204855
# 177                 100.9         117.480378
# 693                  34.3          41.337994
# 1410                 31.2          31.108369
# 1055                 84.1         106.539027
# ...                   ...                ...
# 1215                118.5         114.926009
# 1227                159.1         130.521858
# 438                 100.2         109.457746
# 510                 116.2         112.029698
# 1256                 60.9          48.830064
#
# [975 rows x 21 columns]

# %%
df_lagged.tail(11)
# Out:
#      receiver_player_id posteam  season receiver_player_name  pass      xTDs  \
# 517          00-0037816      GB    2022              R.Doubs    67  2.460143
# 604          00-0037838     BAL    2022             I.Likely    60  3.282421
# 1438         00-0038041     DAL    2022           J.Ferguson    22  0.889236
# 1143         00-0038090      KC    2022              S.Moore    33  0.630063
# 747          00-0038104      NE    2022           T.Thornton    45  3.189822
# 1164         00-0038115     NYG    2022          D.Bellinger    35  0.778236
# 1215         00-0038117     NYG    2022           W.Robinson    31  0.639919
# 1227         00-0038120     NYJ    2022              Br.Hall    31  1.119950
# 438          00-0038124      GB    2022             C.Watson    66  5.519179
# 510          00-0038129      TB    2022              C.Otton    65  4.337548
# 1256         00-0038134     SEA    2022             K.Walker    35  0.138136
#
#       pass_touchdown      xYards  yards_gained         cp  ...  \
# 517              3.0  541.177368         425.0  44.964937  ...
# 604              3.0  429.492950         373.0  40.330922  ...
# 1438             2.0  140.835526         174.0  16.795957  ...
# 1143             0.0  265.516174         250.0  23.407232  ...
# 747              2.0  401.870117         247.0  26.600075  ...
# 1164             2.0  223.158844         268.0  24.952157  ...
# 1215             1.0  224.932175         227.0  22.078208  ...
# 1227             1.0  192.434555         218.0  21.799425  ...
# 438              7.0  560.143677         611.0  38.034695  ...
# 510              2.0  437.800903         391.0  45.103641  ...
# 1256             0.0  174.778717         165.0  28.066606  ...
#
#       fantasy_points  compositeXFP  xTDs_next  pass_touchdown_next  \
# 517            102.5    113.843535   7.057438                  8.0
# 604             91.3    102.974743   1.520924                  5.0
# 1438            48.4     36.214927   7.028761                  5.0
# 1143            47.0     53.739227   1.906371                  1.0
# 747             58.7     85.926019   0.560133                  0.0
# 1164            68.8     51.937460   0.132343                  0.0
# 1215            51.7     48.410937   1.013247                  1.0
# 1227            46.8     47.762584   1.113889                  4.0
# 438            144.1    127.164136   6.148241                  5.0
# 510             93.1    114.909020   3.377167                  4.0
# 1256            49.5     46.373292   0.277406                  1.0
#
#       xYards_next  yards_gained_next    cp_next  complete_pass_next  \
# 517    774.804138              674.0  57.829159                59.0
# 604    284.859711              411.0  27.930377                30.0
# 1438   647.428467              761.0  71.300789                71.0
# 1143   288.433990              244.0  24.452009                21.0
# 747    184.883804               91.0  15.103351                13.0
# 1164   197.065216              255.0  21.681777                25.0
# 1215   527.911743              525.0  56.055348                60.0
# 1227   498.789948              591.0  73.959531                76.0
# 438    439.387939              422.0  28.629502                28.0
# 510    453.356232              452.0  46.431071                47.0
# 1256   185.228836              259.0  28.642744                29.0
#
#       fantasy_points_next  compositeXFP_next
# 517                 174.4         177.654206
# 604                 101.1          65.541892
# 1438                177.1         178.216204
# 1143                 51.4          64.733635
# 747                  22.1          36.952529
# 1164                 50.5          42.182356
# 1215                118.5         114.926009
# 1227                159.1         130.521858
# 438                 100.2         109.457746
# 510                 116.2         112.029698
# 1256                 60.9          48.830064
#
# [11 rows x 21 columns]

# %%
correlations = {}

# Loop through each stat to calculate its correlation with the following season
for col in ['xTDs', 'pass_touchdown', 'xYards', 'yards_gained', 'cp', 'complete_pass', 'fantasy_points', 'compositeXFP']:
    correlation = df_lagged[col].corr(df_lagged[f'{col}_next'])
    #print(df_lagged)
    correlations[col] = correlation

# Display the results
correlations_df = pd.DataFrame.from_dict(correlations, orient='index', columns=['Correlation with Next Season'])
print(correlations_df)
# Out:
#                 Correlation with Next Season
# xTDs                                0.637433
# pass_touchdown                      0.487664
# xYards                              0.712754
# yards_gained                        0.687642
# cp                                  0.611072
# complete_pass                       0.620011
# fantasy_points                      0.662647
# compositeXFP                        0.678315

# %%
#correlations_df.drop(['xFPs'],inplace=True)

# %%
correlations = {}

# Loop through each stat to calculate its correlation with the following season
for metric in ['pass_touchdown', 'yards_gained', 'complete_pass','fantasy_points']:
    if metric == 'pass_touchdown':
        predictor = 'xTDs'
    if metric == 'yards_gained':
        predictor = 'xYards'
    if metric == 'complete_pass':
        predictor = 'cp'
    if metric == 'fantasy_points':
        predictor = 'compositeXFP'
    #print(f"{predictor} to predict {metric}")
    correlation = df_lagged[predictor].corr(df_lagged[f'{metric}_next'])
    correlations[metric] = correlation

# Display the results
x_stat_correlations_df = pd.DataFrame.from_dict(correlations, orient='index', columns=['Expected Stat Correlation with Actual Next Season Target'])
print(x_stat_correlations_df)
# Out:
#                 Expected Stat Correlation with Actual Next Season Target
# pass_touchdown                                           0.518442
# yards_gained                                             0.679533
# complete_pass                                            0.604711
# fantasy_points                                           0.647800

# %%
correlations_df.merge(x_stat_correlations_df,right_index=True,left_index=True,how='outer').sort_values('Correlation with Next Season',ascending=False)
# Out:
#                 Correlation with Next Season  \
# xYards                              0.712754
# yards_gained                        0.687642
# compositeXFP                        0.678315
# fantasy_points                      0.662647
# xTDs                                0.637433
# complete_pass                       0.620011
# cp                                  0.611072
# pass_touchdown                      0.487664
#
#                 Expected Stat Correlation with Actual Next Season Target
# xYards                                                        NaN
# yards_gained                                             0.679533
# compositeXFP                                                  NaN
# fantasy_points                                           0.647800
# xTDs                                                          NaN
# complete_pass                                            0.604711
# cp                                                            NaN
# pass_touchdown                                           0.518442

# %%
df_lagged[['xTDs','pass_touchdown','pass_touchdown_next']].corr()
# Out:
#                          xTDs  pass_touchdown  pass_touchdown_next
# xTDs                 1.000000        0.824104             0.518442
# pass_touchdown       0.824104        1.000000             0.487664
# pass_touchdown_next  0.518442        0.487664             1.000000

# %%
df_lagged[['xYards','yards_gained','yards_gained_next']].corr()
# Out:
#                      xYards  yards_gained  yards_gained_next
# xYards             1.000000      0.962869           0.679533
# yards_gained       0.962869      1.000000           0.687642
# yards_gained_next  0.679533      0.687642           1.000000

# %%
df_lagged
# Out:
#      receiver_player_id posteam  season receiver_player_name  pass      xTDs  \
# 159          00-0022921     ARI    2018         L.Fitzgerald   112  6.013919
# 177          00-0022921     ARI    2019         L.Fitzgerald   107  6.194704
# 693          00-0022943      NO    2018             B.Watson    46  4.364765
# 1410         00-0025394     WAS    2018           A.Peterson    26  0.480599
# 1055         00-0025396      NO    2018               T.Ginn    30  2.373526
# ...                 ...     ...     ...                  ...   ...       ...
# 1215         00-0038117     NYG    2022           W.Robinson    31  0.639919
# 1227         00-0038120     NYJ    2022              Br.Hall    31  1.119950
# 438          00-0038124      GB    2022             C.Watson    66  5.519179
# 510          00-0038129      TB    2022              C.Otton    65  4.337548
# 1256         00-0038134     SEA    2022             K.Walker    35  0.138136
#
#       pass_touchdown      xYards  yards_gained         cp  ...  \
# 159              6.0  880.963379         734.0  72.544649  ...
# 177              4.0  798.765869         835.0  73.160045  ...
# 693              2.0  365.639679         400.0  29.137302  ...
# 1410             1.0  143.061844         208.0  20.414077  ...
# 1055             2.0  283.107178         209.0  17.385297  ...
# ...              ...         ...           ...        ...  ...
# 1215             1.0  224.932175         227.0  22.078208  ...
# 1227             1.0  192.434555         218.0  21.799425  ...
# 438              7.0  560.143677         611.0  38.034695  ...
# 510              2.0  437.800903         391.0  45.103641  ...
# 1256             0.0  174.778717         165.0  28.066606  ...
#
#       fantasy_points  compositeXFP  xTDs_next  pass_touchdown_next  \
# 159            178.4    196.724504   6.194704                  4.0
# 177            192.5    190.204855   2.071367                  1.0
# 693             87.0     91.889861   1.378371                  0.0
# 1410            46.8     37.603855   0.367350                  0.0
# 1055            49.9     59.937171   4.056949                  2.0
# ...              ...           ...        ...                  ...
# 1215            51.7     48.410937   1.013247                  1.0
# 1227            46.8     47.762584   1.113889                  4.0
# 438            144.1    127.164136   6.148241                  5.0
# 510             93.1    114.909020   3.377167                  4.0
# 1256            49.5     46.373292   0.277406                  1.0
#
#       xYards_next  yards_gained_next    cp_next  complete_pass_next  \
# 159    798.765869              835.0  73.160045                73.0
# 177    524.440125              409.0  52.608162                54.0
# 693    176.140900              173.0  15.453680                17.0
# 1410   109.799454              142.0  17.924322                17.0
# 1055   499.710510              421.0  32.226284                30.0
# ...           ...                ...        ...                 ...
# 1215   527.911743              525.0  56.055348                60.0
# 1227   498.789948              591.0  73.959531                76.0
# 438    439.387939              422.0  28.629502                28.0
# 510    453.356232              452.0  46.431071                47.0
# 1256   185.228836              259.0  28.642744                29.0
#
#       fantasy_points_next  compositeXFP_next
# 159                 192.5         190.204855
# 177                 100.9         117.480378
# 693                  34.3          41.337994
# 1410                 31.2          31.108369
# 1055                 84.1         106.539027
# ...                   ...                ...
# 1215                118.5         114.926009
# 1227                159.1         130.521858
# 438                 100.2         109.457746
# 510                 116.2         112.029698
# 1256                 60.9          48.830064
#
# [975 rows x 21 columns]

# %% [markdown]
# # Intra-season Comparison

# %%
    # we only want throws to a receiver, aka plays with air yardage (no running plays, sacks, throwaways etc.)
    throws = data[data['air_yards'].notna()]
    # only data before the current szn
    throws = throws[throws['season']!=2024]
    throws = throws[throws['receiver_player_name'].notna()]
    throws = throws[throws['pass_location'].notna()]

    
    df = throws[['receiver_player_name','receiver_player_id','posteam','pass','cp','game_id','complete_pass','inside_10','air_yards','yardline_100','ydstogo','implied_posteam_total','yards_gained','fantasy_points','pass_touchdown','down','pass_location','week','season','home_implied_total','away_implied_total','posteam_type','qb_hit','end_zone_target', 'distance_to_EZ_after_target']]

# %%
new_predictors = [
    'air_yards', 'yardline_100', 'ydstogo',
    'down', 'pass_location', 'season', 'qb_hit', 'end_zone_target', 'distance_to_EZ_after_target'
]

test_df = df[new_predictors]

test_df.head()
# Out:
#     air_yards  yardline_100  ydstogo  down pass_location  season  qb_hit  \
# 2         8.0          80.0       15   1.0         right    2018     0.0
# 5         4.0          39.0       10   1.0         right    2018     0.0
# 6        -3.0          39.0       10   2.0          left    2018     0.0
# 7        24.0          39.0       10   3.0          left    2018     0.0
# 10        1.0           1.0        1   3.0         right    2018     0.0
#
#     end_zone_target  distance_to_EZ_after_target
# 2             False                         72.0
# 5             False                         35.0
# 6             False                         42.0
# 7             False                         15.0
# 10             True                          0.0

# %%
    
    # we only want throws to a receiver, aka plays with air yardage (no running plays, sacks, throwaways etc.)
    throws = data[data['air_yards'].notna()]
    # only data before the current szn
    throws = throws[throws['season']!=2024]
    throws = throws[throws['receiver_player_name'].notna()]
    throws = throws[throws['pass_location'].notna()]

    
    df = throws[['receiver_player_name','receiver_player_id','posteam','pass','cp','game_id','complete_pass','inside_10','air_yards','yardline_100','ydstogo','implied_posteam_total','yards_gained','fantasy_points','pass_touchdown','down','pass_location','week','season','home_implied_total','away_implied_total','posteam_type','qb_hit','end_zone_target', 'distance_to_EZ_after_target']]

# %%
test_df = pd.get_dummies(test_df, columns=['pass_location'], drop_first=True)


# Add predictions to the new dataset (optional)
df['xYards'] = yardage_model.predict(test_df)
df['xTDs'] = touchdown_model.predict(test_df)
#df['xFPs'] = best_model.predict(test_df)
df['compositeXFP'] = df['cp'] * ppr + df['xTDs'] * 6 + df['xYards'] * 0.1
# Out:
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\1150515730.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xYards'] = yardage_model.predict(test_df)
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\1150515730.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['xTDs'] = touchdown_model.predict(test_df)
# C:\Users\src15\AppData\Local\Temp\ipykernel_20984\1150515730.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['compositeXFP'] = df['cp'] * ppr + df['xTDs'] * 6 + df['xYards'] * 0.1

# %%
# Filter weeks 1-9 and weeks 10-18
first_half = df[df['week'].between(1, 9)]
second_half = df[df['week'].between(10, 18)]

# Define metrics to aggregate
metrics = ['pass','xTDs', 'pass_touchdown', 'xYards', 'yards_gained', 'cp', 'complete_pass',  'fantasy_points', 'compositeXFP']

# Aggregate metrics for each player-season for weeks 1-9
first_half_agg = first_half.groupby(['receiver_player_id', 'season'])[metrics].sum()
first_half_agg = first_half_agg.add_suffix('_wk1_9')

# Aggregate metrics for each player-season for weeks 10-18
second_half_agg = second_half.groupby(['receiver_player_id', 'season'])[metrics].sum()
second_half_agg = second_half_agg.add_suffix('_wk10_18')

# Merge the two aggregated DataFrames
df_aggregated = pd.merge(first_half_agg, second_half_agg, left_index=True, right_index=True)

# %%
df_aggregated = df_aggregated[(df_aggregated['pass_wk1_9'] >= 5) & (df_aggregated['pass_wk10_18'] >= 5)]

# %%
# Create a dictionary to store correlations for each metric
correlations = {}

# Calculate correlation for each metric between weeks 1-9 and weeks 10-18
for metric in metrics:
    correlation = df_aggregated[f'{metric}_wk1_9'].corr(df_aggregated[f'{metric}_wk10_18'])
    correlations[metric] = correlation

# Display the correlation results
correlations_df = pd.DataFrame.from_dict(correlations, orient='index', columns=['Correlation between Weeks 1-9 and 10-18'])
print(correlations_df)
# Out:
#                 Correlation between Weeks 1-9 and 10-18
# pass                                           0.712226
# xTDs                                           0.575760
# pass_touchdown                                 0.420054
# xYards                                         0.751190
# yards_gained                                   0.711520
# cp                                             0.687478
# complete_pass                                  0.686201
# fantasy_points                                 0.688007
# compositeXFP                                   0.721260

# %%
df_aggregated[['fantasy_points_wk1_9','compositeXFP_wk1_9','fantasy_points_wk10_18']].corr()
# Out:
#                         fantasy_points_wk1_9  compositeXFP_wk1_9  \
# fantasy_points_wk1_9                1.000000            0.956836
# compositeXFP_wk1_9                  0.956836            1.000000
# fantasy_points_wk10_18              0.688007            0.686945
#
#                         fantasy_points_wk10_18
# fantasy_points_wk1_9                  0.688007
# compositeXFP_wk1_9                    0.686945
# fantasy_points_wk10_18                1.000000

# %%
df_aggregated[['yards_gained_wk1_9','xYards_wk1_9','yards_gained_wk10_18']].corr()
# Out:
#                       yards_gained_wk1_9  xYards_wk1_9  yards_gained_wk10_18
# yards_gained_wk1_9              1.000000      0.952486              0.711520
# xYards_wk1_9                    0.952486      1.000000              0.705179
# yards_gained_wk10_18            0.711520      0.705179              1.000000

# %%
df_aggregated[['pass_touchdown_wk1_9','xTDs_wk1_9','pass_touchdown_wk10_18']].corr()
# Out:
#                         pass_touchdown_wk1_9  xTDs_wk1_9  \
# pass_touchdown_wk1_9                1.000000    0.781575
# xTDs_wk1_9                          0.781575    1.000000
# pass_touchdown_wk10_18              0.420054    0.459065
#
#                         pass_touchdown_wk10_18
# pass_touchdown_wk1_9                  0.420054
# xTDs_wk1_9                            0.459065
# pass_touchdown_wk10_18                1.000000
